# %% [markdown]
# # ERASE THIS FILE LATER

# %%
import numpy as np
import pandas as pd

# %%
price_stockA = [110,120,130,140]
price_stockA
# Out:
# [110, 120, 130, 140]

# %%
price_stockA[:-1]
# Out:
# [110, 120, 130]

# %%
price_stockA[-3:]
# Out:
# [120, 130, 140]

# %%
price_stockA[-3:]/price_stockA[:-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 price_stockA[-3:]/price_stockA[:-1]
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
price_stockA = np.array([110,120,130,140])

# %%
price_stockA[-3:]/price_stockA[:-1]
# Out:
# array([1.09090909, 1.08333333, 1.07692308])

# %%
PriceAll_Excel = pd.read_excel("C:/Users/Irsyad/Downloads/Data, Sumber, Kalkulasi.xlsx")
PriceAll_Excel.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN       2013        NaN       2014        NaN       2015
# 1         NaN   February     August   February     August   February
# 2         1.0       AALI       AALI       AALI       AALI       AALI
# 3         2.0       ADRO       ADRO       ADHI       ADHI       ADHI
# 4         3.0       AKRA       AKRA       ADRO       ADRO       ADRO
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 15 Unnamed: 16  \
# 0        NaN       2016        NaN       2017  ...        2020         NaN
# 1     August   February     August   February  ...    February      August
# 2       AALI       AALI       AALI       AALI  ...        ACES        ACES
# 3       ADHI       ADHI       ADHI       ADHI  ...        ADRO        ADRO
# 4       ADRO       ADRO       ADRO       ADRO  ...        AKRA        AKRA
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# ...

# %%
PriceAll_Csv = pd.read_csv("C:/Users/Irsyad/Documents/Introduction to Portfolio Construction and Analysis with Python/Python Personal Exercise.csv",sep=";")
PriceAll_Csv
# Out:
#     ADRO  ASII  BBCA  BBNI  BBRI  BMRI   ICBP  INDF   INTP  KLBF  PGAS  PTBA  \
# 0   1570  7950  2200  2300  1718  2513   4250  7300  21950  1290  4800  3020
# 1   1230  7350  1810  1925  1200  1775   5000  6500  19700  1350  5400  2420
# 2    995  6950  2045  2275  1686  2275   5588  7175  22450  1450  4900  1915
# 3   1185  7425  2240  2675  2009  2594   5250  6875  24250  1660  5800  2670
# 4    960  7850  2820  3438  2341  3000   7150  7400  24050  1805  5200  2135
# 5    875  6850  2580  2475  1932  2275   6375  5300  19625  1675  2780  1170
# 6    605  6800  2695  2538  2014  2388   7875  7050  20025  1300  2635  1015
# 7    730  6725  3010  2938  2118  2806   9975  7925  17700  1795  3020  1985
# 8   1695  8200  3090  3125  2173  2825   8325  8125  15150  1530  2830  2235
# 9   1775  8950  3790  3675  2750  3275   8725  8375  19800  1710  2120  2475
# 10  2350  8075  4635  4863  3436  4150   8975  7575  21975  1600  2670  3170
# ...

# %%
print(PriceAll_Csv.dtypes)
# Out:
# ADRO    int64
# ASII    int64
# BBCA    int64
# BBNI    int64
# BBRI    int64
# BMRI    int64
# ICBP    int64
# INDF    int64
# INTP    int64
# KLBF    int64
# PGAS    int64
# PTBA    int64
# SMGR    int64
# TLKM    int64
# UNTR    int64
# UNVR    int64
# dtype: object

# %%
PercentageAll_Csv = PriceAll_Csv.pct_change()
PercentageAll_Csv
# Out:
#         ADRO      ASII      BBCA      BBNI      BBRI      BMRI      ICBP  \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  -0.216561 -0.075472 -0.177273 -0.163043 -0.301513 -0.293673  0.176471
# 2  -0.191057 -0.054422  0.129834  0.181818  0.405000  0.281690  0.117600
# 3   0.190955  0.068345  0.095355  0.175824  0.191578  0.140220 -0.060487
# 4  -0.189873  0.057239  0.258929  0.285234  0.165256  0.156515  0.361905
# 5  -0.088542 -0.127389 -0.085106 -0.280105 -0.174712 -0.241667 -0.108392
# 6  -0.308571 -0.007299  0.044574  0.025455  0.042443  0.049670  0.235294
# 7   0.206612 -0.011029  0.116883  0.157604  0.051639  0.175042  0.266667
# 8   1.321918  0.219331  0.026578  0.063649  0.025968  0.006771 -0.165414
# 9   0.047198  0.091463  0.226537  0.176000  0.265532  0.159292  0.048048
# 10  0.323944 -0.097765  0.222955  0.323265  0.249455  0.267176  0.028653
# 11 -0.219149 -0.114551  0.070119 -0.198026 -0.158615 -0.168675 -0.033426
# ...

# %%
PercentageAll_Csv.plot()
# Out:
# <Axes: >

# %%
PercentageAll_Csv.plot.bar()
# Out:
# <Axes: >

# %%
PercentageAll_Csv+1
# Out:
#         ADRO      ASII      BBCA      BBNI      BBRI      BMRI      ICBP  \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   0.783439  0.924528  0.822727  0.836957  0.698487  0.706327  1.176471
# 2   0.808943  0.945578  1.129834  1.181818  1.405000  1.281690  1.117600
# 3   1.190955  1.068345  1.095355  1.175824  1.191578  1.140220  0.939513
# 4   0.810127  1.057239  1.258929  1.285234  1.165256  1.156515  1.361905
# 5   0.911458  0.872611  0.914894  0.719895  0.825288  0.758333  0.891608
# 6   0.691429  0.992701  1.044574  1.025455  1.042443  1.049670  1.235294
# 7   1.206612  0.988971  1.116883  1.157604  1.051639  1.175042  1.266667
# 8   2.321918  1.219331  1.026578  1.063649  1.025968  1.006771  0.834586
# 9   1.047198  1.091463  1.226537  1.176000  1.265532  1.159292  1.048048
# 10  1.323944  0.902235  1.222955  1.323265  1.249455  1.267176  1.028653
# 11  0.780851  0.885449  1.070119  0.801974  0.841385  0.831325  0.966574
# ...

# %%
np.prod(PercentageAll_Csv+1)-1
# Out:
# c:\Users\Irsyad\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# ADRO    0.993631
# ASII   -0.150943
# BBCA    3.170455
# BBNI    0.994783
# BBRI    2.230501
# BMRI    1.397533
# ICBP    1.635294
# INDF   -0.027397
# INTP   -0.512528
# KLBF    0.406977
# PGAS   -0.713542
# PTBA   -0.052980
# SMGR   -0.606982
# TLKM    0.734884
# UNTR    0.347150
# UNVR   -0.196937
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
PriceAll_Csv
# Out:
#     ADRO  ASII  BBCA  BBNI  BBRI  BMRI   ICBP  INDF   INTP  KLBF  PGAS  PTBA  \
# 0   1570  7950  2200  2300  1718  2513   4250  7300  21950  1290  4800  3020
# 1   1230  7350  1810  1925  1200  1775   5000  6500  19700  1350  5400  2420
# 2    995  6950  2045  2275  1686  2275   5588  7175  22450  1450  4900  1915
# 3   1185  7425  2240  2675  2009  2594   5250  6875  24250  1660  5800  2670
# 4    960  7850  2820  3438  2341  3000   7150  7400  24050  1805  5200  2135
# 5    875  6850  2580  2475  1932  2275   6375  5300  19625  1675  2780  1170
# 6    605  6800  2695  2538  2014  2388   7875  7050  20025  1300  2635  1015
# 7    730  6725  3010  2938  2118  2806   9975  7925  17700  1795  3020  1985
# 8   1695  8200  3090  3125  2173  2825   8325  8125  15150  1530  2830  2235
# 9   1775  8950  3790  3675  2750  3275   8725  8375  19800  1710  2120  2475
# 10  2350  8075  4635  4863  3436  4150   8975  7575  21975  1600  2670  3170
# ...

# %%
Column = list(PriceAll_Csv)
Column
# Out:
# ['ADRO',
#  'ASII',
#  'BBCA',
#  'BBNI',
#  'BBRI',
#  'BMRI',
#  'ICBP',
#  'INDF',
#  'INTP',
#  'KLBF',
#  'PGAS',
#  'PTBA',
#  'SMGR',
#  'TLKM',
#  'UNTR',
#  'UNVR']

# %%
BeginningVal = PriceAll_Csv.iloc[0]
BeginningVal
# Out:
# ADRO     1570
# ASII     7950
# BBCA     2200
# BBNI     2300
# BBRI     1718
# BMRI     2513
# ICBP     4250
# INDF     7300
# INTP    21950
# KLBF     1290
# PGAS     4800
# PTBA     3020
# SMGR    17302
# TLKM     2150
# UNTR    19300
# UNVR     4570
# Name: 0, dtype: int64

# %%
EndingVal = PriceAll_Csv.iloc[21]
EndingVal
# Out:
# ADRO     3130
# ASII     6750
# BBCA     9175
# BBNI     4588
# BBRI     5550
# BMRI     6025
# ICBP    11200
# INDF     7100
# INTP    10700
# KLBF     1815
# PGAS     1375
# PTBA     2860
# SMGR     6800
# TLKM     3730
# UNTR    26000
# UNVR     3670
# Name: 21, dtype: int64

# %%
CAGR = (EndingVal/BeginningVal)**(1/22)-1
CAGR
# Out:
# ADRO    0.031859
# ASII   -0.007410
# BBCA    0.067063
# BBNI    0.031886
# BBRI    0.054748
# BMRI    0.040548
# ICBP    0.045030
# INDF   -0.001262
# INTP   -0.032133
# KLBF    0.015641
# PGAS   -0.055241
# PTBA   -0.002471
# SMGR   -0.041562
# TLKM    0.025359
# UNTR    0.013637
# UNVR   -0.009920
# dtype: float64

# %%
(0.031859+1)**22-1
# Out:
# 0.9936450685964364

# %%
#to make it into 2 digits
#expressed in %

(CAGR*100).round(2)
# Out:
# ADRO    3.19
# ASII   -0.74
# BBCA    6.71
# BBNI    3.19
# BBRI    5.47
# BMRI    4.05
# ICBP    4.50
# INDF   -0.13
# INTP   -3.21
# KLBF    1.56
# PGAS   -5.52
# PTBA   -0.25
# SMGR   -4.16
# TLKM    2.54
# UNTR    1.36
# UNVR   -0.99
# dtype: float64

# %%
PriceAll_Csv.head()
# Out:
#    ADRO  ASII  BBCA  BBNI  BBRI  BMRI  ICBP  INDF   INTP  KLBF  PGAS  PTBA  \
# 0  1570  7950  2200  2300  1718  2513  4250  7300  21950  1290  4800  3020
# 1  1230  7350  1810  1925  1200  1775  5000  6500  19700  1350  5400  2420
# 2   995  6950  2045  2275  1686  2275  5588  7175  22450  1450  4900  1915
# 3  1185  7425  2240  2675  2009  2594  5250  6875  24250  1660  5800  2670
# 4   960  7850  2820  3438  2341  3000  7150  7400  24050  1805  5200  2135
#
#     SMGR  TLKM   UNTR  UNVR
# 0  17302  2150  19300  4570
# 1  12565  2200  15800  6240
# 2  14958  2325  18975  5715
# 3  16180  2665  22150  6205
# 4  14834  2935  20750  7200

# %%
PriceAll_Csv.std()
# Out:
# ADRO     791.816094
# ASII    1158.424815
# BBCA    2393.796365
# BBNI     860.167768
# BBRI    1173.665713
# BMRI     977.682957
# ICBP    2068.940142
# INDF     779.572984
# INTP    4855.174890
# KLBF     216.507101
# PGAS    1506.091904
# PTBA     863.910995
# SMGR    2982.484240
# TLKM     760.198802
# UNTR    5918.797213
# UNVR    2269.255795
# dtype: float64

# %%
Stdv_inPercent = (PercentageAll_Csv.std()*100).round(2)
Stdv_inPercent
# Out:
# ADRO    40.85
# ASII    17.20
# BBCA    10.59
# BBNI    19.86
# BBRI    19.25
# BMRI    16.53
# ICBP    15.04
# INDF    14.36
# INTP    15.28
# KLBF    17.65
# PGAS    22.77
# PTBA    33.98
# SMGR    16.38
# TLKM    15.32
# UNTR    20.88
# UNVR    18.97
# dtype: float64

# %%
PercentageAll_Csv.mean()
# Out:
# ADRO    0.089496
# ASII    0.006183
# BBCA    0.075470
# BBNI    0.051695
# BBRI    0.074707
# BMRI    0.055997
# ICBP    0.057356
# INDF    0.008737
# INTP   -0.022193
# KLBF    0.030890
# PGAS   -0.031301
# PTBA    0.046106
# SMGR   -0.029789
# TLKM    0.037515
# UNTR    0.034067
# UNVR    0.008132
# dtype: float64

# %%
Montly_PortReturn = 0.01
Annualized = (1+Montly_PortReturn)**12-1
Annualized
# Out:
# 0.12682503013196977

# %%
Quarterly_PortReturn = 0.02
Annualized_Quarter = (1+Quarterly_PortReturn)**4-1
Annualized_Quarter
# Out:
# 0.08243215999999998

# %%
Daily_PortReturn = 0.001
Annualized_Daily = (1+Daily_PortReturn)**252-1
Annualized_Daily
# Out:
# 0.28643404437615216

# %%
PercentageAll_Csv.shape
# Out:
# (22, 16)

# %%
PercentageAll_Csv.shape[0]
# Out:
# 22

# %%
PercentageAll_Csv.shape[1]
# Out:
# 16

# %%
deviations = PercentageAll_Csv - PercentageAll_Csv.mean()
squared_deviations = deviations**2
variance = squared_deviations.mean()

volatility = np.sqrt(variance)
volatility
# Out:
# ADRO    0.398653
# ASII    0.167881
# BBCA    0.103308
# BBNI    0.193804
# BBRI    0.187815
# BMRI    0.161316
# ICBP    0.146784
# INDF    0.140131
# INTP    0.149165
# KLBF    0.172225
# PGAS    0.222167
# PTBA    0.331589
# SMGR    0.159882
# TLKM    0.149540
# UNTR    0.203795
# UNVR    0.185142
# dtype: float64

# %%
number_of_obs = PercentageAll_Csv.shape[0]
mean_squared_deviations = squared_deviations.sum()/(number_of_obs-1)

volatility = np.sqrt(mean_squared_deviations)

volatility
# Out:
# ADRO    0.398653
# ASII    0.167881
# BBCA    0.103308
# BBNI    0.193804
# BBRI    0.187815
# BMRI    0.161316
# ICBP    0.146784
# INDF    0.140131
# INTP    0.149165
# KLBF    0.172225
# PGAS    0.222167
# PTBA    0.331589
# SMGR    0.159882
# TLKM    0.149540
# UNTR    0.203795
# UNVR    0.185142
# dtype: float64

# %%
PercentageAll_Csv.std()*np.sqrt(12)
# Out:
# ADRO    1.415079
# ASII    0.595917
# BBCA    0.366706
# BBNI    0.687935
# BBRI    0.666678
# BMRI    0.572614
# ICBP    0.521031
# INDF    0.497415
# INTP    0.529484
# KLBF    0.611340
# PGAS    0.788615
# PTBA    1.177025
# SMGR    0.567527
# TLKM    0.530815
# UNTR    0.723400
# UNVR    0.657188
# dtype: float64

# %%
PercentageAll_Csv.std()*(12**0.5)
# Out:
# ADRO    1.415079
# ASII    0.595917
# BBCA    0.366706
# BBNI    0.687935
# BBRI    0.666678
# BMRI    0.572614
# ICBP    0.521031
# INDF    0.497415
# INTP    0.529484
# KLBF    0.611340
# PGAS    0.788615
# PTBA    1.177025
# SMGR    0.567527
# TLKM    0.530815
# UNTR    0.723400
# UNVR    0.657188
# dtype: float64

# %%
import pandas as pd
PriceAll_Csv = pd.read_csv("C:/Users/Irsyad/Documents/Introduction to Portfolio Construction and Analysis with Python/Python Personal Exercise.csv", sep=";",
                       header=0, index_col=0, parse_dates=True, na_values=-99.99)
# Out:
# C:\Users\Irsyad\AppData\Local\Temp\ipykernel_8688\683651471.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   PriceAll_Csv = pd.read_csv("C:/Users/Irsyad/Documents/Introduction to Portfolio Construction and Analysis with Python/Python Personal Exercise.csv", sep=";",

# %%
print(type(PriceAll_Csv))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(PriceAll_Csv.columns)
# Out:
# Index(['ASII', 'BBCA', 'BBNI', 'BBRI', 'BMRI', 'ICBP', 'INDF', 'INTP', 'KLBF',
#        'PGAS', 'PTBA', 'SMGR', 'TLKM', 'UNTR', 'UNVR'],
#       dtype='object')

# %%
columns = ["BMRI", "BBCA"]  # Adjust to match the DataFrame column names
PriceAll_Csv = PriceAll_Csv[columns]
PriceAll_Csv
# Out:
#       BMRI  BBCA
# ADRO
# 1570  2513  2200
# 1230  1775  1810
# 995   2275  2045
# 1185  2594  2240
# 960   3000  2820
# 875   2275  2580
# 605   2388  2695
# 730   2806  3010
# 1695  2825  3090
# 1775  3275  3790
# 2350  4150  4635
# 1835  3450  4960
# 1310  3563  5515
# 1305  3625  6100
# 1155  3638  6290
# 920   2975  6275
# 1180  3075  6710
# 1245  3050  6550
# 2450  3850  8050
# 3340  4425  8200
# 2990  5000  8750
# 3130  6025  9175

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
PriceAll_Csv = PriceAll_Csv.reset_index()  # Resets the index, ADRO becomes a regular column
PriceAll_Csv = PriceAll_Csv[columns]  # Select only BMRI and BBCA
print(PriceAll_Csv)
# Out:
#     BMRI  BBCA
# 0   2513  2200
# 1   1775  1810
# 2   2275  2045
# 3   2594  2240
# 4   3000  2820
# 5   2275  2580
# 6   2388  2695
# 7   2806  3010
# 8   2825  3090
# 9   3275  3790
# 10  4150  4635
# 11  3450  4960
# 12  3563  5515
# 13  3625  6100
# 14  3638  6290
# 15  2975  6275
# 16  3075  6710
# 17  3050  6550
# 18  3850  8050
# 19  4425  8200
# 20  5000  8750
# 21  6025  9175

# %%
PriceAll_Csv.plot.bar()
# Out:
# <Axes: >

# %%
Returns_BMRIBCA = PriceAll_Csv.pct_change().iloc[1:22]
Returns_BMRIBCA
# Out:
#         BMRI      BBCA
# 1  -0.293673 -0.177273
# 2   0.281690  0.129834
# 3   0.140220  0.095355
# 4   0.156515  0.258929
# 5  -0.241667 -0.085106
# 6   0.049670  0.044574
# 7   0.175042  0.116883
# 8   0.006771  0.026578
# 9   0.159292  0.226537
# 10  0.267176  0.222955
# 11 -0.168675  0.070119
# 12  0.032754  0.111895
# 13  0.017401  0.106074
# 14  0.003586  0.031148
# 15 -0.182243 -0.002385
# 16  0.033613  0.069323
# 17 -0.008130 -0.023845
# 18  0.262295  0.229008
# 19  0.149351  0.018634
# 20  0.129944  0.067073
# 21  0.205000  0.048571

# %%
Returns_BMRIBCA.shape
# Out:
# (21, 2)

# %%
Returns_BMRIBCA.std()
# Out:
# BMRI    0.165299
# BBCA    0.105859
# dtype: float64

# %%
annualized_vol = Returns_BMRIBCA.std()*np.sqrt(21)
annualized_vol
# Out:
# BMRI    0.757497
# BBCA    0.485106
# dtype: float64

# %%
n_period = Returns_BMRIBCA.shape[0]
return_per_semester = (Returns_BMRIBCA+1).prod()**(1/n_period) - 1
return_per_semester
# Out:
# BMRI    0.042519
# BBCA    0.070367
# dtype: float64

# %%
annualized_return = (return_per_semester+1)**2-1

#2 because 1 year consist of 2 semester.

annualized_return
# Out:
# BMRI    0.086846
# BBCA    0.145685
# dtype: float64

# %%
annualized_return/annualized_vol
# Out:
# BMRI    0.114649
# BBCA    0.300315
# dtype: float64

# %%
riskfree_rate = 0.03

excess_return = annualized_return - riskfree_rate
sharpe_ratio = excess_return/annualized_vol

sharpe_ratio
# Out:
# BMRI    0.075045
# BBCA    0.238473
# dtype: float64

# %% [markdown]
# It means, adjusted risk to return for BBCA is far more superior than BMRI within 2011-2023 period
